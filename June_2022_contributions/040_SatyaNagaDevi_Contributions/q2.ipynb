# %%
a=int(input("enter first num:"))
b=int(input("enter second num:"))
maximum=print(max(a,b))
minimum=print(min(a,b))
average=(a+b)/2
print(average)
add=print(a+b)
mul=print(a*b)
# Out:
# enter first num:23
# enter second num:34
# 34
# 23
# 28.5
# 57
# 782
